# %% [markdown]
# ### MLML Seawater Intake

# %% [markdown]
# The goal of this exercise is to use principal component analysis to summarize relationships between co-varying variables measured at the MLML seawater intake.
#
# Starter code is provided for loading and plotting the data. The principal component analysis can be conducted using the [kelp example](2-monterey_bay_kelp.ipynb) as a template.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import dates

filename = 'data/mlml_seawater/2016-08.csv'
df = pd.read_csv(filename,parse_dates=[0,1])

# %%
df.head()
# Out:
#                    utc_time            pst_time   unix_time       temp  \
# 0 2016-08-02 00:08:18+00:00 2016-08-01 16:08:18  1470096498  15.228153
# 1 2016-08-02 00:13:17+00:00 2016-08-01 16:13:17  1470096797  15.974306
# 2 2016-08-02 00:18:17+00:00 2016-08-01 16:18:17  1470097097  17.537585
# 3 2016-08-02 00:23:18+00:00 2016-08-01 16:23:18  1470097398  17.275320
# 4 2016-08-02 00:28:17+00:00 2016-08-01 16:28:17  1470097697  15.020288
#
#    temp_flg      cond  cond_flg        sal  sal_flg     fluor  ...  osat_flg  \
# 0         9  0.959019         9  33.201665        9  6.694133  ...         9
# 1         9  0.967580         9  32.903808        9  6.643340  ...         9
# 2         1  0.991139         1  32.507648        1  2.078260  ...         1
# 3         1  0.994248         1  32.833492        3  2.122705  ...         1
# 4         1  0.954494         1  33.202816        1  1.284610  ...         1
#
#    tide        ph  ph_flg  phrawv  co2  temp_raw  cond_raw  fluoro_raw  \
# ...

# %%
all_vars = ['temp','sal','do2','ph','trans','fluor']

ii = np.ones(np.shape(df['temp_flg']),dtype=bool)
for var in all_vars:
    goodi = df[var+'_flg']==1
    ii = ii & goodi

for var in all_vars:
    plt.figure()
    plt.plot(df['pst_time'][ii],df[var][ii])
    plt.title(var)
    dfmt = dates.DateFormatter('%b %d')
    plt.gca().xaxis.set_major_formatter(dfmt)

# %% [markdown]
# a) Building off the starter code in the notebook, explore relationships between the different variables by making scatter plots. Which variables appear to be correlated with each other?

# %%
# insert code here

# %% [markdown]
# *insert text here*

# %% [markdown]
# b)  Compute and plot the factor loadings and principal component scores. Use your plots to explain relationships among the variables.

# %%
# insert code here

# %% [markdown]
# *Insert text here*
